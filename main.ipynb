# %%
import pandas as pd
from re import sub
from FileReader import File_Reader
from numpy import transpose as t
from numpy import matrix as mat, matmul as mm
import math as m
import numpy as np
import pandas as pd
from LeastSquares import LS

f = File_Reader()

#one error found so far is that in the 'engo531_lab1.ext' file extra tabs are used which means that the file needs to be cleaned in order to properly read in the data
#second error was found from additional tabs in the int file
#int file also contain inconsistant spacing delimeters which resulted in additional processing
    
f.pho

# %%
from FileReader import File_Reader
File_Reader().con.sort_index()
# Out:
#              X     Y     Z
# point_id
# A32       -760   988  -547
# A33       -182  1555  -541
# A34        392  2122  -547
# A35        976  2703  -558
# A5          47  1788  1982
# AS10       236  1982  1751
# AS12      -381  1373  1464
# AS31      -868   889 -1222
# AS32       840  2581 -1196
# AVS104    -761   983  -898
# AVS105    -476  1261  -874
# AVS106    -192  1543  -895
# AVS107     101  1834  -885
# AVS108     394  2128  -914
# AVS116     393  2129 -1352
# AVS117     953  2683 -1334
# AVS50       63  1799  1628
# AVS51      345  2075  1623
# AVS57     -513  1229  1230
# AVS58       60  1792  1236
# AVS59      630  2361  1248
# AVS65     -796   945   776
# AVS69      358  2093   784
# AVS70      641  2371   777
# AVS71      956  2682   797
# AVS75     -794   946   402
# AVS91     1318  3040    -5
# B1        1646  3052  1258
# B2        2225  2490  1254
# B8        1667  3038   489
# B9        2215  2506   461
# BS11      1585  3128   249
# BS17      1767  2956  -796
# BS20      2562  2179 -1033
# BS8       2559  2177   701
# BVS10     1941  2766  1253
# BVS16     2747  1983   879
# BVS35     2240  2480  -400
# BVS36     1598  3109  -358
# BVS37     1739  2973  -614
# BVS38     2766  1968  -810
# BVS42     1605  3101  -868
# BVS43     2495  2234 -1205
# BVS44     1967  2747 -1192
# BVS5      2444  2271  1610
# BVS6      2212  2498  1613
